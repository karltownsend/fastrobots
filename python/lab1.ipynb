# %% [markdown]
# ## Import necessary modules
# Run this cell before running any other cells

# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2024-10-19 10:28:53,353 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:ec:f2:c2:23:04
# 2024-10-19 10:28:56,503 | INFO     |: Connected to c0:ec:f2:c2:23:04
# /Users/karlt/Documents/GitHub/fastrobots/python/base_ble.py:104: FutureWarning: This method will be removed future version, pass the callback to the BleakClient constructor instead.
#   self.client.set_disconnected_callback(self.disconnect_handler)

# %%
ble.send_command(CMD.PING, "")

# %%
s = ble.receive_string(ble.uuid['RX_STRING'])
print(s)
# Out:
# PONG

# %%
ble.send_command(CMD.SEND_TWO_INTS, "2|-6")

# %% [markdown]
# The Artemis board should print the two integers to the serial monitor in the ArduinoIDE.

# %%
# Tasks
ble.send_command(CMD.ECHO, "HiHello")
print(ble.receive_string(ble.uuid['RX_STRING']))
# Out:
# Robot says -> HiHello :)

# %%
# Notification Handler
time_list = []
temp_list = []
def notification_handler(uuid, byte_array):
    rx_string = ble.bytearray_to_string(byte_array)
    if rx_string.find(',') < 0:
        print(rx_string[2:])
    else:
        time, temp = rx_string.split(',')
        time_list.append(time[2:])
        temp_list.append(temp[2:])

ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 13
#      10         time_list.append(time[2:])
#      11         temp_list.append(temp[2:])
# ---> 13 ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
#
# File ~/Documents/GitHub/fastrobots/python/ble.py:81, in BaseBLEController.start_notify(self, uuid, notification_handler)
#      80 def start_notify(self, uuid, notification_handler):
# ---> 81     self._wait(self.device._start_notify(uuid, notification_handler))
#
# File ~/Documents/GitHub/fastrobots/python/base_ble.py:27, in wait_b(coroutine)
#      26 def wait_b(coroutine):
# ---> 27     return asyncio.run(coroutine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/Documents/GitHub/fastrobots/python/base_ble.py:129, in BLEAsyncDevice._start_notify(self, uuid, notification_handler)
#     127 async def _start_notify(self, uuid, notification_handler):
#     128     if self.client and self.client.is_connected:
# --> 129         await self.client.start_notify(uuid, notification_handler)
#     130     else:
#     131         raise Exception("Not connected to a BLE device")
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bleak/__init__.py:844, in BleakClient.start_notify(self, char_specifier, callback, **kwargs)
#     841 else:
#     842     wrapped_callback = functools.partial(callback, characteristic)
# --> 844 await self._backend.start_notify(characteristic, wrapped_callback, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bleak/backends/corebluetooth/client.py:364, in BleakClientCoreBluetooth.start_notify(self, characteristic, callback, **kwargs)
#     359 """
#     360 Activate notifications/indications on a characteristic.
#     361 """
#     362 assert self._delegate is not None
# --> 364 await self._delegate.start_notifications(characteristic.obj, callback)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/bleak/backends/corebluetooth/PeripheralDelegate.py:221, in PeripheralDelegate.start_notifications(self, characteristic, callback)
#     219 c_handle = characteristic.handle()
#     220 if c_handle in self._characteristic_notify_callbacks:
# --> 221     raise ValueError("Characteristic notifications already started")
#     223 self._characteristic_notify_callbacks[c_handle] = callback
#     225 future = self._event_loop.create_future()
#
# ValueError: Characteristic notifications already started

# %%
ble.send_command(CMD.GET_TIME_MILLIS, "")
# Out:
# 68526

# %%
ble.send_command(CMD.GET_TIME_MILLIS_LOOP, "")
# Out:
# 72548
# 72548
# 72548
# 72549
# 72549
# 72549
# 72550
# 72579
# 72579
# 72579
# 72580
# 72580
# 72580
# 72607
# 72607
# 72607
# 72607
# 72608
# 72608
# 72636
# 72636
# 72637
# 72637
# 72637
# 72637
# 72664
# 72672
# 72672
# 72672
# 72673
# 72673
# 72699
# 72699
# 72699
# 72700
# 72700
# 72700
# 72729
# 72729
# 72729
# 72729
# 72730
# 72730
# 72756
# 72756
# 72756
# 72757
# 72757
# 72757
# 72791
# 72791
# 72791
# 72791
# 72792
# 72792
# 72817
# 72817
# 72817
# 72818
# 72818
# 72818
# 72846
# 72846
# 72847
# 72847
# 72847
# 72847
# 72881
# 72881
# 72881
# 72881
# 72882
# 72882
# 72905
# 72905
# 72905
# 72905
# 72915
# 72915
# 72942
# 72942
# 72942
# 72943
# 72943
# 72943
# 72970
# 72970
# 72970
# 72970
# 72971
# 72971
# 72996
# 72996
# 72996
# 72997
# 72997
# 72997
# 73026
# 73026
# 73026
# 73053
# 73060
# 73060
# 73091
# 73091
# 73091
# 73092
# 73121
# 73121
# 73121
# 73147
# 73147
# 73147
# 73177
# 73177
# 73177
# 73177
# 73211
# 73211
# 73211
# 73235
# 73235
# 73235
# 73265
# 73265
# 73265
# 73265
# 73301
# 73301
# 73301
# 73328
# 73328
# 73328
# 73358
# 73358
# 73358
# 73358
# 73388
# 73388
# 73388
# 73418
# 73418
# 73418
# 73444
# 73454
# 73454
# 73454
# 73481
# 73481
# 73481
# 73511
# 73511
# 73511
# 73511
# 73541
# 73541
# 73568
# 73568
# 73568
# 73568
# 73594
# 73604
# 73604
# 73624
# 73634
# 73634
# 73654
# 73664
# 73664
# 73664
# 73684
# 73694
# 73694
# 73721
# 73721
# 73721
# 73721
# 73747
# 73747
# 73747
# 73776
# 73776
# 73776
# 73810
# 73810
# 73810
# 73811
# 73838
# 73838
# 73838
# 73865
# 73865
# 73865
# 73899
# 73899
# 73899
# 73899
# 73925
# 73925
# 73925
# 73955
# 73955
# 73985
# 74015
# 74015
# 74015
# 74015
# 74048
# 74048
# 74081
# 74110
# 74110
# 74110
# 74141
# 74141
# 74141
# 74171
# 74198
# 74198
# 74198
# 74227
# 74227
# 74227
# 74255
# 74285
# 74285
# 74285
# 74321
# 74321
# 74321
# 74351
# 74377
# 74377
# 74377
# 74407
# 74407
# 74437
# 74437
# 74467
# 74467
# 74467
# 74497
# 74497
# 74527
# 74527

ble.connect()# Notification Handler
# Out:
# 2024-08-02 13:25:51,114 | INFO     |: Already connected to a BLE device

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()# Notification Handler

def notification_handler(uuid, byte_array):
    timestamp = ble.bytearray_to_string(byte_array)[2:]
    print('Time:', timestamp)

ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
# Out:
# 2024-08-03 10:25:27,311 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:ec:f2:c2:23:04
# 2024-08-03 10:25:30,250 | INFO     |: Connected to c0:ec:f2:c2:23:04

# %%
ble.send_command(CMD.GET_TIME_MILLIS, "")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ble.send_command(CMD.GET_TIME_MILLIS, "")
#
# File ~/Documents/python/cornell/mae4190/ble_python/ble.py:151, in ArtemisBLEController.send_command(self, cmd_type, data)
#     148 cmd_string = str(cmd_type.value) + ":" + str(data)
#     150 if len(cmd_string) < self.max_write_length:
# --> 151     self.write(self.uuid['TX_CMD_STRING'], bytearray(map(ord, cmd_string)))
#     152 else:
#     153     raise Exception("Cannot write string larger than {} bytes".format(
#     154         self.max_write_length))
#
# File ~/Documents/python/cornell/mae4190/ble_python/ble.py:75, in BaseBLEController.write(self, uuid, byte_array)
#      74 def write(self, uuid, byte_array):
# ---> 75     self._wait(self.device._write(uuid, byte_array))
#
# File ~/Documents/python/cornell/mae4190/ble_python/base_ble.py:27, in wait_b(coroutine)
#      26 def wait_b(coroutine):
# ---> 27     return asyncio.run(coroutine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/Documents/python/cornell/mae4190/ble_python/base_ble.py:119, in BLEAsyncDevice._write(self, uuid, byte_array)
#     117     await self.client.write_gatt_char(uuid, byte_array,response=True)
#     118 else:
# --> 119     raise Exception("Not connected to a BLE device")
#
# Exception: Not connected to a BLE device

# %%
ble.send_command(CMD.GET_TIME_MILLIS_LOOP, "")
# Out:
# Time: 7536200
# Time: 7536200
# Time: 7536201
# Time: 7536201
# Time: 7536201
# Time: 7536201
# Time: 7536202
# Time: 7536226
# Time: 7536226
# Time: 7536260
# Time: 7536260
# Time: 7536261
# Time: 7536290
# Time: 7536290
# Time: 7536290
# Time: 7536291
# Time: 7536317
# Time: 7536317
# Time: 7536346
# Time: 7536346
# Time: 7536347
# Time: 7536347
# Time: 7536375
# Time: 7536382
# Time: 7536382
# Time: 7536406
# Time: 7536406
# Time: 7536407
# Time: 7536437
# Time: 7536437
# Time: 7536437
# Time: 7536438
# Time: 7536471
# Time: 7536471
# Time: 7536496
# Time: 7536496
# Time: 7536496
# Time: 7536497
# Time: 7536529
# Time: 7536529
# Time: 7536529
# Time: 7536555
# Time: 7536555
# Time: 7536556
# Time: 7536585
# Time: 7536585
# Time: 7536586
# Time: 7536620
# Time: 7536620
# Time: 7536621
# Time: 7536650
# Time: 7536650
# Time: 7536650
# Time: 7536679
# Time: 7536679
# Time: 7536679
# Time: 7536706
# Time: 7536706
# Time: 7536706
