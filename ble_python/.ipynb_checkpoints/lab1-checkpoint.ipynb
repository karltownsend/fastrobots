# %% [markdown]
# ## Import necessary modules
# Run this cell before running any other cells

# %%
# %load_ext autoreload
# %autoreload 2

from ble import get_ble_controller
from base_ble import LOG
from cmd_types import CMD
import time
import numpy as np

LOG.propagate = False

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()
# Out:
# 2024-08-03 19:15:55,475 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:ec:f2:c2:23:04
# 2024-08-03 19:15:58,451 | INFO     |: Connected to c0:ec:f2:c2:23:04
# /Users/karlt/Documents/python/cornell/mae4190/ble_python/base_ble.py:104: FutureWarning: This method will be removed future version, pass the callback to the BleakClient constructor instead.
#   self.client.set_disconnected_callback(self.disconnect_handler)

# %% [markdown]
# ## Receive data from the Artemis board

# %% [markdown]
# The cell below shows examples of reading different types (as defined in the Arduino sketch) of GATT characteristics.

# %%
# Read a float GATT Charactersistic
f = ble.receive_float(ble.uuid['RX_FLOAT'])
print(f)
# Out:
# 5.0

# %%
# Read a string GATT Charactersistic
s = ble.receive_string(ble.uuid['RX_STRING'])
print(s)
# Out:
# [->9.0<-]

# %% [markdown]
# ## Send a command to the Artemis board
# Send the PING command and read the reply string from the string characteristic RX_STRING. <br>
# __NOTE__: The **send_command()** essentially sends a string data to the GATT characteristic (TX_CMD_STRING). The GATT characteristic in the Arduino sketch is of type BLECStringCharacteristic.

# %%
ble.send_command(CMD.PING, "")

# %%
s = ble.receive_string(ble.uuid['RX_STRING'])
print(s)
# Out:
# PONG

# %% [markdown]
# The cell below shows an example of the SEND_TWO_INTS command. <br> The two values in the **data** are separated by a delimiter "|". <br>
# Refer Lab 2 documentation for more information on the command protocol.

# %%
ble.send_command(CMD.SEND_TWO_INTS, "2|-6")

# %% [markdown]
# The Artemis board should print the two integers to the serial monitor in the ArduinoIDE.

# %%
# Tasks
ble.send_command(CMD.ECHO, "HiHello")
print(ble.receive_string(ble.uuid['RX_STRING']))
# Out:
# Time: bot says -> HiHello :)
# Robot says -> HiHello :)

# %%
# Notification Handler
time_list = []
temp_list = []
def notification_handler(uuid, byte_array):
    rx_string = ble.bytearray_to_string(byte_array)
    if rx_string.find(',') < 0:
        print(rx_string[2:])
    else:
        time, temp = rx_string.split(',')
        time_list.append(time[2:])
        temp_list.append(temp[2:])

ble.start_notify(ble.uuid['RX_STRING'], notification_handler)

# %%
ble.send_command(CMD.GET_TIME_MILLIS, "")
# Out:
# 31770904

# %%
# Store data in the array
ble.send_command(CMD.STORE_TIME_DATA, "")

# %%
# Get the data
# 500 samples in 13 ms, --> 270KB/sec!
ble.send_command(CMD.SEND_TIME_DATA, "")
# Out:
# 31775180
# 31775180
# 31775181
# 31775181
# 31775181
# 31775181
# 31775181
# 31775182
# 31775182
# 31775182
# 31775182
# 31775183
# 31775183
# 31775183
# 31775183
# 31775184
# 31775184
# 31775184
# 31775184
# 31775184
# 31775185
# 31775185
# 31775185
# 31775185
# 31775186
# 31775189
# 31775189
# 31775189
# 31775190
# 31775190
# 31775190
# 31775190
# 31775190
# 31775191
# 31775191
# 31775191
# 31775191
# 31775192
# 31775192
# 31775192
# 31775192
# 31775192
# 31775193
# 31775193
# 31775193
# 31775193
# 31775194
# 31775194
# 31775194
# 31775194
# 31775195
# 31775199
# 31775199
# 31775199
# 31775200
# 31775200
# 31775200
# 31775200
# 31775200
# 31775201
# 31775201
# 31775271
# 31775271
# 31775271
# 31775273
# 31775273
# 31775273
# 31775273
# 31775274
# 31775274
# 31775274
# 31775274
# 31775275
# 31775275
# 31775275
# 31775275
# 31775275
# 31775276
# 31775276
# 31775276
# 31775276
# 31775277
# 31775277
# 31775277
# 31775277
# 31775277
# 31775278
# 31775278
# 31775278
# 31775278
# 31775279
# 31775279
# 31775279
# 31775279
# 31775280
# 31775280
# 31775280
# 31775280
# 31775281
# 31775281
# 31775281
# 31775281
# 31775281
# 31775282
# 31775282
# 31775282
# 31775282
# 31775283
# 31775283
# 31775283
# 31775283
# 31775283
# 31775284
# 31775284
# 31775284
# 31775284
# 31775285
# 31775288
# 31775288
# 31775288
# 31775289
# 31775289
# 31775289
# 31775289
# 31775289
# 31775290
# 31775290
# 31775290
# 31775290
# 31775291
# 31775291
# 31775291
# 31775291
# 31775292
# 31775292
# 31775292
# 31775292
# 31775292
# 31775293
# 31775293
# 31775293
# 31775293
# 31775294
# 31775295
# 31775295
# 31775295
# 31775296
# 31775296
# 31775296
# 31775296
# 31775296
# 31775297
# 31775297
# 31775297
# 31775297
# 31775298
# 31775298
# 31775298
# 31775298
# 31775298
# 31775299
# 31775299
# 31775299
# 31775299
# 31775300
# 31775300
# 31775300
# 31775300
# 31775301
# 31775302
# 31775302
# 31775302
# 31775303
# 31775303
# 31775303
# 31775303
# 31775303
# 31775304
# 31775304
# 31775304
# 31775304
# 31775305
# 31775305
# 31775305
# 31775305
# 31775305
# 31775306
# 31775306
# 31775306
# 31775306
# 31775307
# 31775307
# 31775307
# 31775307
# 31775308
# 31775309
# 31775309
# 31775309
# 31775310
# 31775310
# 31775310
# 31775310
# 31775310
# 31775311
# 31775311
# 31775311
# 31775311
# 31775312
# 31775312
# 31775312
# 31775312
# 31775312
# 31775313
# 31775313
# 31775313
# 31775313
# 31775314
# 31775314
# 31775314
# 31775314
# 31775315
# 31775316
# 31775316
# 31775316
# 31775316
# 31775317
# 31775317
# 31775317
# 31775317
# 31775318
# 31775318
# 31775318
# 31775318
# 31775319
# 31775319
# 31775319
# 31775319
# 31775319
# 31775320
# 31775320
# 31775320
# 31775320
# 31775321
# 31775321
# 31775321
# 31775321
# 31775321
# 31775323
# 31775323
# 31775323
# 31775323
# 31775324
# 31775324

# %%
# Get the data
# 500 samples in 13 ms, --> 270KB/sec!
global time_list
global temp_list
time_list = []
temp_list = []
ble.send_command(CMD.STORE_TIME_DATA, "")

# %%
# Get the data
# 500 samples in 13 ms, --> 270KB/sec!
ble.send_command(CMD.GET_TEMP_READINGS, "")
print(len(time_list), len(temp_list))
# Out:
# 778 778

# %% [markdown]
# ## Disconnect

# %%
# Disconnect
ble.disconnect()
# Out:
# 2024-08-02 22:39:43,652 | INFO     |: Disconnected from E8E0F7A4-7773-8749-3CAD-EADBED93F90E

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()# Notification Handler
# Out:
# 2024-08-02 13:25:51,114 | INFO     |: Already connected to a BLE device

# %%
# Get ArtemisBLEController object
ble = get_ble_controller()

# Connect to the Artemis Device
ble.connect()# Notification Handler

def notification_handler(uuid, byte_array):
    timestamp = ble.bytearray_to_string(byte_array)[2:]
    print('Time:', timestamp)

ble.start_notify(ble.uuid['RX_STRING'], notification_handler)
# Out:
# 2024-08-03 10:25:27,311 | INFO     |: Looking for Artemis Nano Peripheral Device: c0:ec:f2:c2:23:04
# 2024-08-03 10:25:30,250 | INFO     |: Connected to c0:ec:f2:c2:23:04

# %%
ble.send_command(CMD.GET_TIME_MILLIS, "")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 ble.send_command(CMD.GET_TIME_MILLIS, "")
#
# File ~/Documents/python/cornell/mae4190/ble_python/ble.py:151, in ArtemisBLEController.send_command(self, cmd_type, data)
#     148 cmd_string = str(cmd_type.value) + ":" + str(data)
#     150 if len(cmd_string) < self.max_write_length:
# --> 151     self.write(self.uuid['TX_CMD_STRING'], bytearray(map(ord, cmd_string)))
#     152 else:
#     153     raise Exception("Cannot write string larger than {} bytes".format(
#     154         self.max_write_length))
#
# File ~/Documents/python/cornell/mae4190/ble_python/ble.py:75, in BaseBLEController.write(self, uuid, byte_array)
#      74 def write(self, uuid, byte_array):
# ---> 75     self._wait(self.device._write(uuid, byte_array))
#
# File ~/Documents/python/cornell/mae4190/ble_python/base_ble.py:27, in wait_b(coroutine)
#      26 def wait_b(coroutine):
# ---> 27     return asyncio.run(coroutine)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:30, in _patch_asyncio.<locals>.run(main, debug)
#      28 task = asyncio.ensure_future(main)
#      29 try:
# ---> 30     return loop.run_until_complete(task)
#      31 finally:
#      32     if not task.done():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/futures.py:203, in Future.result(self)
#     201 self.__log_traceback = False
#     202 if self._exception is not None:
# --> 203     raise self._exception.with_traceback(self._exception_tb)
#     204 return self._result
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/asyncio/tasks.py:314, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     310 try:
#     311     if exc is None:
#     312         # We use the `send` method directly, because coroutines
#     313         # don't have `__iter__` and `__next__` methods.
# --> 314         result = coro.send(None)
#     315     else:
#     316         result = coro.throw(exc)
#
# File ~/Documents/python/cornell/mae4190/ble_python/base_ble.py:119, in BLEAsyncDevice._write(self, uuid, byte_array)
#     117     await self.client.write_gatt_char(uuid, byte_array,response=True)
#     118 else:
# --> 119     raise Exception("Not connected to a BLE device")
#
# Exception: Not connected to a BLE device

# %%
ble.send_command(CMD.GET_TIME_MILLIS_LOOP, "")
# Out:
# Time: 7536200
# Time: 7536200
# Time: 7536201
# Time: 7536201
# Time: 7536201
# Time: 7536201
# Time: 7536202
# Time: 7536226
# Time: 7536226
# Time: 7536260
# Time: 7536260
# Time: 7536261
# Time: 7536290
# Time: 7536290
# Time: 7536290
# Time: 7536291
# Time: 7536317
# Time: 7536317
# Time: 7536346
# Time: 7536346
# Time: 7536347
# Time: 7536347
# Time: 7536375
# Time: 7536382
# Time: 7536382
# Time: 7536406
# Time: 7536406
# Time: 7536407
# Time: 7536437
# Time: 7536437
# Time: 7536437
# Time: 7536438
# Time: 7536471
# Time: 7536471
# Time: 7536496
# Time: 7536496
# Time: 7536496
# Time: 7536497
# Time: 7536529
# Time: 7536529
# Time: 7536529
# Time: 7536555
# Time: 7536555
# Time: 7536556
# Time: 7536585
# Time: 7536585
# Time: 7536586
# Time: 7536620
# Time: 7536620
# Time: 7536621
# Time: 7536650
# Time: 7536650
# Time: 7536650
# Time: 7536679
# Time: 7536679
# Time: 7536679
# Time: 7536706
